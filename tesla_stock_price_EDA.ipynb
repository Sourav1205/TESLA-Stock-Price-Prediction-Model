# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_tesla=pd.read_csv(r"c:\Users\Sourav\Desktop\Practice\Machine Learning\TESLA Stock Price Prediction Project\Tesla Stock Price (2010 to 2023).csv")

# %%
df_tesla.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume  \
# 0  29/06/2010  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1  30/06/2010  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2    1/7/2010  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3    2/7/2010  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4    6/7/2010  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#    SMA       CMA  EMA
# 0  NaN       NaN  NaN
# 1  NaN  1.493000  NaN
# 2  NaN  1.693000  NaN
# 3  NaN  1.600000  NaN
# 4  NaN  1.433333  NaN

# %%
type(df_tesla)
# Out:
# pandas.core.frame.DataFrame

# %%
df_tesla.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3157   12/1/2023  122.559998  124.129997  117.000000  123.559998  123.559998
# 3158  13/01/2023  116.550003  122.629997  115.599998  122.400002  122.400002
# 3159  17/01/2023  125.699997  131.699997  125.019997  131.490005  131.490005
# 3160  18/01/2023  136.559998  136.679993  127.010002  128.779999  128.779999
# 3161  19/01/2023  127.260002  129.990005  124.309998  127.169998  127.169998
#
#          Volume  SMA  CMA  EMA
# 3157  169400900  NaN  NaN  NaN
# 3158  180439300  NaN  NaN  NaN
# 3159  186477000  NaN  NaN  NaN
# 3160  195680300  NaN  NaN  NaN
# 3161  169883300  NaN  NaN  NaN

# %%
df_tesla['Date']=pd.to_datetime(df_tesla.Date)
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\3361918159.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_tesla['Date']=pd.to_datetime(df_tesla.Date)

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
import plotly.express as px

# %%
fig=px.line(df_tesla,x=df_tesla.index,y="High")
fig.show()

# %%
df_tesla['High'].plot(figsize=(20,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].plot(xlim=['2020-12-01','2023-01-19'],ylim=[0,500],figsize=(12,4),ls='--',c='red')
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  SMA  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500  NaN
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500  NaN
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000  NaN
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000  NaN
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500  NaN
#
#                  CMA  EMA
# Date
# 2010-06-29       NaN  NaN
# 2010-06-30  1.493000  NaN
# 2010-07-01  1.693000  NaN
# 2010-07-02  1.600000  NaN
# 2010-07-06  1.433333  NaN

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-17',
#                '2023-01-18', '2023-01-19'],
#               dtype='datetime64[ns]', name='Date', length=3162, freq=None)

# %%
index = df_tesla.loc['2020-12-01':'2023-01-19'].index
index
# Out:
# DatetimeIndex(['2020-12-01', '2020-12-02', '2020-12-03', '2020-12-04',
#                '2020-12-07', '2020-12-08', '2020-12-09', '2020-12-10',
#                '2020-12-11', '2020-12-14',
#                ...
#                '2023-01-05', '2023-01-06', '2023-01-09', '2023-01-10',
#                '2023-01-11', '2023-01-12', '2023-01-13', '2023-01-17',
#                '2023-01-18', '2023-01-19'],
#               dtype='datetime64[ns]', name='Date', length=537, freq=None)

# %%
stock_open=df_tesla.loc['2020-12-01':'2023-01-19']['Open']
stock_open
# Out:
# Date
# 2020-12-01    199.196671
# 2020-12-02    185.479996
# 2020-12-03    196.673340
# 2020-12-04    197.003326
# 2020-12-07    201.639999
#                  ...
# 2023-01-12    122.559998
# 2023-01-13    116.550003
# 2023-01-17    125.699997
# 2023-01-18    136.559998
# 2023-01-19    127.260002
# Name: Open, Length: 537, dtype: float64

# %%
plt.figure(figsize=(12,4))
fig=px.line(df_tesla,x=df_tesla.index,y="Open")
fig.show()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3162 entries, 2010-06-29 to 2023-01-19
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3162 non-null   float64
#  1   High       3162 non-null   float64
#  2   Low        3162 non-null   float64
#  3   Close      3162 non-null   float64
#  4   Adj Close  3162 non-null   float64
#  5   Volume     3162 non-null   int64
#  6   SMA        119 non-null    float64
#  7   CMA        7 non-null      float64
#  8   EMA        146 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 376.1 KB

# %%
df_tesla.reset_index()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3157 2023-01-12  122.559998  124.129997  117.000000  123.559998  123.559998
# 3158 2023-01-13  116.550003  122.629997  115.599998  122.400002  122.400002
# 3159 2023-01-17  125.699997  131.699997  125.019997  131.490005  131.490005
# 3160 2023-01-18  136.559998  136.679993  127.010002  128.779999  128.779999
# 3161 2023-01-19  127.260002  129.990005  124.309998  127.169998  127.169998
#
#          Volume  SMA       CMA  EMA
# ...

# %%
df_tesla.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  SMA  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500  NaN
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500  NaN
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000  NaN
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000  NaN
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500  NaN
#
#                  CMA  EMA
# Date
# 2010-06-29       NaN  NaN
# 2010-06-30  1.493000  NaN
# 2010-07-01  1.693000  NaN
# 2010-07-02  1.600000  NaN
# 2010-07-06  1.433333  NaN

# %%
datetime(2021,11,12)
# Out:
# datetime.datetime(2021, 11, 12, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 4, 24, 22, 12, 55, 537711)

# %%
date=datetime(2021,11,12)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 12)

# %%
date.day
# Out:
# 12

# %%
date.weekday()
# Out:
# 4

# %% [markdown]
# Time Resampling

# %%
df_tesla.resample(rule="A")
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\3081040239.py:1: FutureWarning:
#
# 'A' is deprecated and will be removed in a future version, please use 'YE' instead.

# %%
df_tesla.resample(rule="A").min()
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\1417667943.py:1: FutureWarning:
#
# 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# ...

# %%
df_tesla.resample(rule="A").max()
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\1640792762.py:1: FutureWarning:
#
# 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# ...

# %%
# year end frequency
df_tesla.resample(rule="A").max()['Open'].plot()
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\901627434.py:2: FutureWarning:
#
# 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
# <Axes: xlabel='Date'>

# %%
#quaterly
df_tesla.resample(rule="QS").max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-04-01    1.719333    2.028000    1.553333    1.592667    1.592667
# 2010-07-01    1.666667    1.728000    1.408667    1.465333    1.465333
# 2010-10-01    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-01-01    1.906000    1.914000    1.870000    1.896667    1.896667
# 2011-04-01    2.006667    2.100000    1.970000    2.009333    2.009333
# 2011-07-01    1.992667    2.029333    1.934000    1.982000    1.982000
# 2011-10-01    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-01-01    2.546000    2.663333    2.474000    2.529333    2.529333
# 2012-04-01    2.488667    2.564667    2.444667    2.534000    2.534000
# 2012-07-01    2.333333    2.400000    2.260000    2.397333    2.397333
# 2012-10-01    2.350667    2.386667    2.330000    2.352000    2.352000
# 2013-01-01    2.630000    2.666667    2.609333    2.632000    2.632000
# ...

# %%
df_tesla.resample(rule="QS").max()["High"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla["Open"].resample(rule="BA").max().plot(kind='bar')
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\500702830.py:1: FutureWarning:
#
# 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
# <Axes: xlabel='Date'>

# %%
df_tesla["High"].rolling(10).mean().head(20)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01         NaN
# 2010-07-02         NaN
# 2010-07-06         NaN
# 2010-07-07         NaN
# 2010-07-08         NaN
# 2010-07-09         NaN
# 2010-07-12         NaN
# 2010-07-13    1.421333
# 2010-07-14    1.389000
# 2010-07-15    1.329533
# 2010-07-16    1.298733
# 2010-07-19    1.293067
# 2010-07-20    1.305400
# 2010-07-21    1.333867
# 2010-07-22    1.358733
# 2010-07-23    1.383133
# 2010-07-26    1.406000
# 2010-07-27    1.422933
# Name: High, dtype: float64

# %%
df_tesla['open: 30 days Rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
df_tesla[["Open","open: 30 days Rolling"]].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
fig=px.line(df_tesla,x=df_tesla.index,y=["Open","open: 30 days Rolling"])
fig.show()

# %%
df_tesla["High"].resample(rule="A").max()
# Out:
# C:\Users\Sourav\AppData\Local\Temp\ipykernel_25688\3772341822.py:1: FutureWarning:
#
# 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
# Date
# 2010-12-31      2.428000
# 2011-12-31      2.333333
# 2012-12-31      2.663333
# 2013-12-31     12.966667
# 2014-12-31     19.427999
# 2015-12-31     19.110001
# 2016-12-31     17.955999
# 2017-12-31     25.974001
# 2018-12-31     25.830667
# 2019-12-31     29.020666
# 2020-12-31    239.573334
# 2021-12-31    414.496674
# 2022-12-31    402.666656
# 2023-12-31    136.679993
# Freq: YE-DEC, Name: High, dtype: float64

# %%
#max price from 2017 to 2022
df_slice=df_tesla['2017':'2022']

# %%
df_stock_max=df_slice["High"].max()
df_stock_max
# Out:
# 414.496674

# %%
#date of highest price of stock
date_highest_price=df_tesla['High'].idxmax()
date_highest_price
# Out:
# Timestamp('2021-11-04 00:00:00')

# %%
#date of lowest price of stock
date_lowest_price=df_tesla['High'].idxmin()
date_lowest_price
# Out:
# Timestamp('2010-07-07 00:00:00')
